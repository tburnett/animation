# %%
# from animation.ipynb_show import show
# import matplotlib.pyplot as plt
import os
os.environ['ANIMATION_FILES'] = 'files'
from animation.plot_job import *

flux_data   =   filepath/'weekly_flux_maps.pkl'
exposure_data = filepath/'weekly_exposure_maps.pkl'
demo_week=291

# %%
from animation.ipynb_show import show
show("""# Single week displays
## Flux""")
show("""* Weekly average""")

show(FluxPlot(flux_data,
              colorbar=True, log=True, vmin=0.1, vmax=10)(0));

show(f"""*  A single week, {demo_week} -- the difference""")
fig = FluxPlot(flux_data, colorbar=True)(demo_week)
show(fig)
# Out:
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f7b6019b850>
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f7b29d11310>
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f7b2466e910>
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f7b1a5474f0>
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f7b1a3b3220>

# %%
show("""## Exposure 
* Full exposure in cm2 s
""")
       
show(ExposurePlot(exposure_data, colorbar=True,show_sun=False,
             cblabel='cm2 s', cmap='coolwarm',  vmax=None)( week=0) )     
show("""* A single week--ratio to the average.
Note the sun position path.""")
show(ExposurePlot(exposure_data,colorbar=True)(demo_week))
# Out:
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7fb70f084c40>
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7fb70f04ed60>
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7fb70cde6e80>
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7fb70cd0d3a0>
